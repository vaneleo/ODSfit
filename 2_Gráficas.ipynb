# %%
import os
import pandas as pd
import numpy as np

# %%
# %pwd
# Out:
# 'C:\\Users\\vlbus\\ODSfit\\scripts'

# %%
#df_1=pd.read_csv('http://localhost:8888/lab/tree/datos/1_archivo_final.csv', sep=',')

#df = pd.read_csv('http://localhost:8888/lab/tree/datos/1_archivo_final.csv')
# Usar encoding='utf-8' para caracteres especiales
df = pd.read_csv('C:\\Users\\vlbus\\ODSfit\\datos\\1_archivo_final.csv')
df
# Out:
#      entidad       n_entidad           nivel   insc_t   hom_t   muj_t  \
# 0          1  aguascalientes         inicial    24641   12925   11716
# 1          1  aguascalientes  media superior   356395  170332  186063
# 2          1  aguascalientes      preescolar   313751  158070  155681
# 3          1  aguascalientes        primaria   958697  487085  471612
# 4          1  aguascalientes      secundaria   446286  224897  221389
# ..       ...             ...             ...      ...     ...     ...
# 155       32       zacatecas         inicial    26409   13508   12901
# 156       32       zacatecas  media superior   389825  180959  208866
# 157       32       zacatecas      preescolar   420715  211539  209176
# 158       32       zacatecas        primaria  1159547  586871  572676
# 159       32       zacatecas      secundaria   530833  266496  264337
#
#      egre_hom  egre_muj  egre_tot  docente_h  docente_m  tot_doc  \
# ...
